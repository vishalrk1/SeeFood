# %% [markdown]
# # SEE FOOD

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

import tensorflow as tf
from tensorflow.keras import layers
from tensorflow.keras.layers import Conv2D, MaxPool2D, Dense, Flatten, Activation
from tensorflow.keras.optimizers import Adam, SGD
from tensorflow.keras import Sequential

# %%
# !nvidia-smi -L
# Out:
# GPU 0: GeForce MX230 (UUID: GPU-ba3b3f04-4bc8-7fef-cec0-4ab6f04f0734)

# %% [markdown]
# ## Helper Function

# %%
from helper_functions import create_tensorboard_callback, plot_loss_curves, pred_and_plot, unzip_data, walk_through_dir, compare_historys, make_confusion_matrix

# %% [markdown]
# # Using Dataset
#
# * **We are using food101 dataset of tensorflow**
# * This dataset consists of 101 food categories, with 101'000 images. For each class, 250 manually reviewed test images are provided as well as 750 training images

# %%
walk_through_dir('data/all_food_classes')
# Out:
# There are 2 directories and 0 images in 'data/all_food_classes'.
# There are 101 directories and 0 images in 'data/all_food_classes\test'.
# There are 0 directories and 250 images in 'data/all_food_classes\test\apple_pie'.
# There are 0 directories and 250 images in 'data/all_food_classes\test\baby_back_ribs'.
# There are 0 directories and 250 images in 'data/all_food_classes\test\baklava'.
# There are 0 directories and 250 images in 'data/all_food_classes\test\beef_carpaccio'.
# There are 0 directories and 250 images in 'data/all_food_classes\test\beef_tartare'.
# There are 0 directories and 250 images in 'data/all_food_classes\test\beet_salad'.
# There are 0 directories and 250 images in 'data/all_food_classes\test\beignets'.
# There are 0 directories and 250 images in 'data/all_food_classes\test\bibimbap'.
# There are 0 directories and 250 images in 'data/all_food_classes\test\bread_pudding'.
# There are 0 directories and 250 images in 'data/all_food_classes\test\breakfast_burrito'.
# There are 0 directories and 250 images in 'data/all_food_classes\test\bruschetta'.
# There are 0 directories and 250 images in 'data/all_food_classes\test\caesar_salad'.
# There are 0 directories and 250 images in 'data/all_food_classes\test\cannoli'.
# There are 0 directories and 250 images in 'data/all_food_classes\test\caprese_salad'.
# There are 0 directories and 250 images in 'data/all_food_classes\test\carrot_cake'.
# There are 0 directories and 250 images in 'data/all_food_classes\test\ceviche'.
# There are 0 directories and 250 images in 'data/all_food_classes\test\cheesecake'.
# There are 0 directories and 250 images in 'data/all_food_classes\test\cheese_plate'.
# There are 0 directories and 250 images in 'data/all_food_classes\test\chicken_curry'.
# There are 0 directories and 250 images in 'data/all_food_classes\test\chicken_quesadilla'.
# There are 0 directories and 250 images in 'data/all_food_classes\test\chicken_wings'.
# There are 0 directories and 250 images in 'data/all_food_classes\test\chocolate_cake'.
# There are 0 directories and 250 images in 'data/all_food_classes\test\chocolate_mousse'.
# There are 0 directories and 250 images in 'data/all_food_classes\test\churros'.
# There are 0 directories and 250 images in 'data/all_food_classes\test\clam_chowder'.
# There are 0 directories and 250 images in 'data/all_food_classes\test\club_sandwich'.
# There are 0 directories and 250 images in 'data/all_food_classes\test\crab_cakes'.
# There are 0 directories and 250 images in 'data/all_food_classes\test\creme_brulee'.
# There are 0 directories and 250 images in 'data/all_food_classes\test\croque_madame'.
# There are 0 directories and 250 images in 'data/all_food_classes\test\cup_cakes'.
# There are 0 directories and 250 images in 'data/all_food_classes\test\deviled_eggs'.
# There are 0 directories and 250 images in 'data/all_food_classes\test\donuts'.
# There are 0 directories and 250 images in 'data/all_food_classes\test\dumplings'.
# There are 0 directories and 250 images in 'data/all_food_classes\test\edamame'.
# There are 0 directories and 250 images in 'data/all_food_classes\test\eggs_benedict'.
# There are 0 directories and 250 images in 'data/all_food_classes\test\escargots'.
# There are 0 directories and 250 images in 'data/all_food_classes\test\falafel'.
# There are 0 directories and 250 images in 'data/all_food_classes\test\filet_mignon'.
# There are 0 directories and 250 images in 'data/all_food_classes\test\fish_and_chips'.
# There are 0 directories and 250 images in 'data/all_food_classes\test\foie_gras'.
# There are 0 directories and 250 images in 'data/all_food_classes\test\french_fries'.
# There are 0 directories and 250 images in 'data/all_food_classes\test\french_onion_soup'.
# There are 0 directories and 250 images in 'data/all_food_classes\test\french_toast'.
# There are 0 directories and 250 images in 'data/all_food_classes\test\fried_calamari'.
# There are 0 directories and 250 images in 'data/all_food_classes\test\fried_rice'.
# There are 0 directories and 250 images in 'data/all_food_classes\test\frozen_yogurt'.
# There are 0 directories and 250 images in 'data/all_food_classes\test\garlic_bread'.
# There are 0 directories and 250 images in 'data/all_food_classes\test\gnocchi'.
# There are 0 directories and 250 images in 'data/all_food_classes\test\greek_salad'.
# There are 0 directories and 250 images in 'data/all_food_classes\test\grilled_cheese_sandwich'.
# There are 0 directories and 250 images in 'data/all_food_classes\test\grilled_salmon'.
# There are 0 directories and 250 images in 'data/all_food_classes\test\guacamole'.
# There are 0 directories and 250 images in 'data/all_food_classes\test\gyoza'.
# There are 0 directories and 250 images in 'data/all_food_classes\test\hamburger'.
# There are 0 directories and 250 images in 'data/all_food_classes\test\hot_and_sour_soup'.
# There are 0 directories and 250 images in 'data/all_food_classes\test\hot_dog'.
# There are 0 directories and 250 images in 'data/all_food_classes\test\huevos_rancheros'.
# There are 0 directories and 250 images in 'data/all_food_classes\test\hummus'.
# There are 0 directories and 250 images in 'data/all_food_classes\test\ice_cream'.
# There are 0 directories and 250 images in 'data/all_food_classes\test\lasagna'.
# There are 0 directories and 250 images in 'data/all_food_classes\test\lobster_bisque'.
# There are 0 directories and 250 images in 'data/all_food_classes\test\lobster_roll_sandwich'.
# There are 0 directories and 250 images in 'data/all_food_classes\test\macaroni_and_cheese'.
# There are 0 directories and 250 images in 'data/all_food_classes\test\macarons'.
# There are 0 directories and 250 images in 'data/all_food_classes\test\miso_soup'.
# There are 0 directories and 250 images in 'data/all_food_classes\test\mussels'.
# There are 0 directories and 250 images in 'data/all_food_classes\test\nachos'.
# There are 0 directories and 250 images in 'data/all_food_classes\test\omelette'.
# There are 0 directories and 250 images in 'data/all_food_classes\test\onion_rings'.
# There are 0 directories and 250 images in 'data/all_food_classes\test\oysters'.
# There are 0 directories and 250 images in 'data/all_food_classes\test\pad_thai'.
# There are 0 directories and 250 images in 'data/all_food_classes\test\paella'.
# There are 0 directories and 250 images in 'data/all_food_classes\test\pancakes'.
# There are 0 directories and 250 images in 'data/all_food_classes\test\panna_cotta'.
# There are 0 directories and 250 images in 'data/all_food_classes\test\peking_duck'.
# There are 0 directories and 250 images in 'data/all_food_classes\test\pho'.
# There are 0 directories and 250 images in 'data/all_food_classes\test\pizza'.
# There are 0 directories and 250 images in 'data/all_food_classes\test\pork_chop'.
# There are 0 directories and 250 images in 'data/all_food_classes\test\poutine'.
# There are 0 directories and 250 images in 'data/all_food_classes\test\prime_rib'.
# There are 0 directories and 250 images in 'data/all_food_classes\test\pulled_pork_sandwich'.
# There are 0 directories and 250 images in 'data/all_food_classes\test\ramen'.
# There are 0 directories and 250 images in 'data/all_food_classes\test\ravioli'.
# There are 0 directories and 250 images in 'data/all_food_classes\test\red_velvet_cake'.
# There are 0 directories and 250 images in 'data/all_food_classes\test\risotto'.
# There are 0 directories and 250 images in 'data/all_food_classes\test\samosa'.
# There are 0 directories and 250 images in 'data/all_food_classes\test\sashimi'.
# There are 0 directories and 250 images in 'data/all_food_classes\test\scallops'.
# There are 0 directories and 250 images in 'data/all_food_classes\test\seaweed_salad'.
# There are 0 directories and 250 images in 'data/all_food_classes\test\shrimp_and_grits'.
# There are 0 directories and 250 images in 'data/all_food_classes\test\spaghetti_bolognese'.
# There are 0 directories and 250 images in 'data/all_food_classes\test\spaghetti_carbonara'.
# There are 0 directories and 250 images in 'data/all_food_classes\test\spring_rolls'.
# There are 0 directories and 250 images in 'data/all_food_classes\test\steak'.
# There are 0 directories and 250 images in 'data/all_food_classes\test\strawberry_shortcake'.
# There are 0 directories and 250 images in 'data/all_food_classes\test\sushi'.
# There are 0 directories and 250 images in 'data/all_food_classes\test\tacos'.
# There are 0 directories and 250 images in 'data/all_food_classes\test\takoyaki'.
# There are 0 directories and 250 images in 'data/all_food_classes\test\tiramisu'.
# There are 0 directories and 250 images in 'data/all_food_classes\test\tuna_tartare'.
# There are 0 directories and 250 images in 'data/all_food_classes\test\waffles'.
# There are 101 directories and 0 images in 'data/all_food_classes\train'.
# There are 0 directories and 750 images in 'data/all_food_classes\train\apple_pie'.
# There are 0 directories and 750 images in 'data/all_food_classes\train\baby_back_ribs'.
# There are 0 directories and 750 images in 'data/all_food_classes\train\baklava'.
# There are 0 directories and 750 images in 'data/all_food_classes\train\beef_carpaccio'.
# There are 0 directories and 750 images in 'data/all_food_classes\train\beef_tartare'.
# There are 0 directories and 750 images in 'data/all_food_classes\train\beet_salad'.
# There are 0 directories and 750 images in 'data/all_food_classes\train\beignets'.
# There are 0 directories and 750 images in 'data/all_food_classes\train\bibimbap'.
# There are 0 directories and 750 images in 'data/all_food_classes\train\bread_pudding'.
# There are 0 directories and 750 images in 'data/all_food_classes\train\breakfast_burrito'.
# There are 0 directories and 750 images in 'data/all_food_classes\train\bruschetta'.
# There are 0 directories and 750 images in 'data/all_food_classes\train\caesar_salad'.
# There are 0 directories and 750 images in 'data/all_food_classes\train\cannoli'.
# There are 0 directories and 750 images in 'data/all_food_classes\train\caprese_salad'.
# There are 0 directories and 750 images in 'data/all_food_classes\train\carrot_cake'.
# There are 0 directories and 750 images in 'data/all_food_classes\train\ceviche'.
# There are 0 directories and 750 images in 'data/all_food_classes\train\cheesecake'.
# There are 0 directories and 750 images in 'data/all_food_classes\train\cheese_plate'.
# There are 0 directories and 750 images in 'data/all_food_classes\train\chicken_curry'.
# There are 0 directories and 750 images in 'data/all_food_classes\train\chicken_quesadilla'.
# There are 0 directories and 750 images in 'data/all_food_classes\train\chicken_wings'.
# There are 0 directories and 750 images in 'data/all_food_classes\train\chocolate_cake'.
# There are 0 directories and 750 images in 'data/all_food_classes\train\chocolate_mousse'.
# There are 0 directories and 750 images in 'data/all_food_classes\train\churros'.
# There are 0 directories and 750 images in 'data/all_food_classes\train\clam_chowder'.
# There are 0 directories and 750 images in 'data/all_food_classes\train\club_sandwich'.
# There are 0 directories and 750 images in 'data/all_food_classes\train\crab_cakes'.
# There are 0 directories and 750 images in 'data/all_food_classes\train\creme_brulee'.
# There are 0 directories and 750 images in 'data/all_food_classes\train\croque_madame'.
# There are 0 directories and 750 images in 'data/all_food_classes\train\cup_cakes'.
# There are 0 directories and 750 images in 'data/all_food_classes\train\deviled_eggs'.
# There are 0 directories and 750 images in 'data/all_food_classes\train\donuts'.
# There are 0 directories and 750 images in 'data/all_food_classes\train\dumplings'.
# There are 0 directories and 750 images in 'data/all_food_classes\train\edamame'.
# There are 0 directories and 750 images in 'data/all_food_classes\train\eggs_benedict'.
# There are 0 directories and 750 images in 'data/all_food_classes\train\escargots'.
# There are 0 directories and 750 images in 'data/all_food_classes\train\falafel'.
# There are 0 directories and 750 images in 'data/all_food_classes\train\filet_mignon'.
# There are 0 directories and 750 images in 'data/all_food_classes\train\fish_and_chips'.
# There are 0 directories and 750 images in 'data/all_food_classes\train\foie_gras'.
# There are 0 directories and 750 images in 'data/all_food_classes\train\french_fries'.
# There are 0 directories and 750 images in 'data/all_food_classes\train\french_onion_soup'.
# There are 0 directories and 750 images in 'data/all_food_classes\train\french_toast'.
# There are 0 directories and 750 images in 'data/all_food_classes\train\fried_calamari'.
# There are 0 directories and 750 images in 'data/all_food_classes\train\fried_rice'.
# There are 0 directories and 750 images in 'data/all_food_classes\train\frozen_yogurt'.
# There are 0 directories and 750 images in 'data/all_food_classes\train\garlic_bread'.
# There are 0 directories and 750 images in 'data/all_food_classes\train\gnocchi'.
# There are 0 directories and 750 images in 'data/all_food_classes\train\greek_salad'.
# There are 0 directories and 750 images in 'data/all_food_classes\train\grilled_cheese_sandwich'.
# There are 0 directories and 750 images in 'data/all_food_classes\train\grilled_salmon'.
# There are 0 directories and 750 images in 'data/all_food_classes\train\guacamole'.
# There are 0 directories and 750 images in 'data/all_food_classes\train\gyoza'.
# There are 0 directories and 750 images in 'data/all_food_classes\train\hamburger'.
# There are 0 directories and 750 images in 'data/all_food_classes\train\hot_and_sour_soup'.
# There are 0 directories and 750 images in 'data/all_food_classes\train\hot_dog'.
# There are 0 directories and 750 images in 'data/all_food_classes\train\huevos_rancheros'.
# There are 0 directories and 750 images in 'data/all_food_classes\train\hummus'.
# There are 0 directories and 750 images in 'data/all_food_classes\train\ice_cream'.
# There are 0 directories and 750 images in 'data/all_food_classes\train\lasagna'.
# There are 0 directories and 750 images in 'data/all_food_classes\train\lobster_bisque'.
# There are 0 directories and 750 images in 'data/all_food_classes\train\lobster_roll_sandwich'.
# There are 0 directories and 750 images in 'data/all_food_classes\train\macaroni_and_cheese'.
# There are 0 directories and 750 images in 'data/all_food_classes\train\macarons'.
# There are 0 directories and 750 images in 'data/all_food_classes\train\miso_soup'.
# There are 0 directories and 750 images in 'data/all_food_classes\train\mussels'.
# There are 0 directories and 750 images in 'data/all_food_classes\train\nachos'.
# There are 0 directories and 750 images in 'data/all_food_classes\train\omelette'.
# There are 0 directories and 750 images in 'data/all_food_classes\train\onion_rings'.
# There are 0 directories and 750 images in 'data/all_food_classes\train\oysters'.
# There are 0 directories and 750 images in 'data/all_food_classes\train\pad_thai'.
# There are 0 directories and 750 images in 'data/all_food_classes\train\paella'.
# There are 0 directories and 750 images in 'data/all_food_classes\train\pancakes'.
# There are 0 directories and 750 images in 'data/all_food_classes\train\panna_cotta'.
# There are 0 directories and 750 images in 'data/all_food_classes\train\peking_duck'.
# There are 0 directories and 750 images in 'data/all_food_classes\train\pho'.
# There are 0 directories and 750 images in 'data/all_food_classes\train\pizza'.
# There are 0 directories and 750 images in 'data/all_food_classes\train\pork_chop'.
# There are 0 directories and 750 images in 'data/all_food_classes\train\poutine'.
# There are 0 directories and 750 images in 'data/all_food_classes\train\prime_rib'.
# There are 0 directories and 750 images in 'data/all_food_classes\train\pulled_pork_sandwich'.
# There are 0 directories and 750 images in 'data/all_food_classes\train\ramen'.
# There are 0 directories and 750 images in 'data/all_food_classes\train\ravioli'.
# There are 0 directories and 750 images in 'data/all_food_classes\train\red_velvet_cake'.
# There are 0 directories and 750 images in 'data/all_food_classes\train\risotto'.
# There are 0 directories and 750 images in 'data/all_food_classes\train\samosa'.
# There are 0 directories and 750 images in 'data/all_food_classes\train\sashimi'.
# There are 0 directories and 750 images in 'data/all_food_classes\train\scallops'.
# There are 0 directories and 750 images in 'data/all_food_classes\train\seaweed_salad'.
# There are 0 directories and 750 images in 'data/all_food_classes\train\shrimp_and_grits'.
# There are 0 directories and 750 images in 'data/all_food_classes\train\spaghetti_bolognese'.
# There are 0 directories and 750 images in 'data/all_food_classes\train\spaghetti_carbonara'.
# There are 0 directories and 750 images in 'data/all_food_classes\train\spring_rolls'.
# There are 0 directories and 750 images in 'data/all_food_classes\train\steak'.
# There are 0 directories and 750 images in 'data/all_food_classes\train\strawberry_shortcake'.
# There are 0 directories and 750 images in 'data/all_food_classes\train\sushi'.
# There are 0 directories and 750 images in 'data/all_food_classes\train\tacos'.
# There are 0 directories and 750 images in 'data/all_food_classes\train\takoyaki'.
# There are 0 directories and 750 images in 'data/all_food_classes\train\tiramisu'.
# There are 0 directories and 750 images in 'data/all_food_classes\train\tuna_tartare'.
# There are 0 directories and 750 images in 'data/all_food_classes\train\waffles'.

# %% [markdown]
# ## Data Inputs

# %%
train_dir = 'data/all_food_classes/train/'
test_dir = 'data/all_food_classes/test/'

# %%
from tensorflow.keras.preprocessing import image_dataset_from_directory
from tensorflow.keras.preprocessing.image import ImageDataGenerator

# %%
IMG_SIZE = (224, 224)
BATCH_SIZE = 32

print('Train Data')
train_data = image_dataset_from_directory(train_dir, label_mode='categorical', batch_size=BATCH_SIZE, image_size=IMG_SIZE)

print('Test Data')
test_data = image_dataset_from_directory(test_dir, label_mode='categorical', batch_size=BATCH_SIZE, image_size=IMG_SIZE)
# Out:
# Train Data
# Found 75750 files belonging to 101 classes.
# Test Data
# Found 25250 files belonging to 101 classes.

# %%
train_data.take(1)
# Out:
# <TakeDataset shapes: ((None, 224, 224, 3), (None, 101)), types: (tf.float32, tf.float32)>

# %% [markdown]
# ## Ploting some random images

# %%
class_names = train_data.class_names

# %%
sample_image = train_data.take(1)

for image, label in sample_image:
    print(f"""
  Image Shape: {image.shape}
  Image datatype: {image.dtype}
  class name: {class_names[label.shape[1]-1]}
  """)
# Out:
#   Image Shape: (32, 224, 224, 3)
#   Image datatype: <dtype: 'float32'>
#   class name: waffles

# %%
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
import random
import os

def view_random_image(target_dir, target_class):
  # setting up target folder
  target_folder = target_dir+target_class
  print(f"target_folder: {target_folder}")

  # get random image form folder
  random_image = random.sample(os.listdir(target_folder),1)
  print(f"Random Image: {random_image}")

  # Reading image and plotting image
  img = mpimg.imread(target_folder + '/' + random_image[0])
  plt.imshow(img)
  plt.title(target_class)
  plt.axis('off');

  print(f"Image Shape: {img.shape}")

  return img

# %%
import random

random_num = random.randint(0,100)
img = view_random_image(target_dir='data/all_food_classes/train/',target_class=class_names[random_num])
# Out:
# target_folder: data/all_food_classes/train/french_fries
# Random Image: ['2429892.jpg']
# Image Shape: (384, 512, 3)

# %% [markdown]
# ## Callbacks

# %%
early_Stopping = tf.keras.callbacks.EarlyStopping(monitor='val_loss', patience=3)

# %%
checkpoint_path = '101_classes_10_percent_data_model_checkpoint'
checkpoint_callback = tf.keras.callbacks.ModelCheckpoint(
    checkpoint_path,
    save_weights_only = True,
    monitor = 'val_accuracy',
    save_best_only = True,
)

# %% [markdown]
# ## Data Augmentation layer

# %%
from tensorflow.keras.layers.experimental import preprocessing

# %%
data_augmentation = tf.keras.Sequential([
    preprocessing.RandomFlip('horizontal'),
    preprocessing.RandomRotation(0.2),
    preprocessing.RandomWidth(0.2),
    preprocessing.RandomHeight(0.2),
    preprocessing.RandomZoom(0.2),
], name='augmentation_layer')

# %% [markdown]
# ## Bulding Model

# %% [markdown]
# * **EfficientNetB0 Model** with no top layers

# %%
#Turning on mixed precision
from tensorflow.keras import mixed_precision

# %%
mixed_precision.set_global_policy('mixed_float16')
# Out:
# WARNING:tensorflow:Mixed precision compatibility check (mixed_float16): WARNING
# The dtype policy mixed_float16 may run slowly because this machine does not have a GPU. Only Nvidia GPUs with compute capability of at least 7.0 run quickly with mixed_float16.
# If you will use compatible GPU(s) not attached to this host, e.g. by running a multi-worker model, you can ignore this warning. This message will only be logged once

# %%
base_model = tf.keras.applications.EfficientNetB0(include_top=False)
base_model.trainable = False

inputs = layers.Input(shape=(224, 224, 3), name='input_layer')
x = data_augmentation(inputs)
x = base_model(x, training=False)
x = layers.GlobalAveragePooling2D()(x)
x = layers.Dense(64, activation='relu')(x)
x = layers.Dense(101)(x)
outputs = layers.Activation('softmax', dtype=tf.float32, name='softmax_float32_layer')(x)

model_1 = tf.keras.Model(inputs, outputs)

# %%
model_1.summary()
# Out:
# Model: "model_2"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_layer (InputLayer)     [(None, 224, 224, 3)]     0
# _________________________________________________________________
# augmentation_layer (Sequenti (None, None, None, 3)     0
# _________________________________________________________________
# efficientnetb0 (Functional)  (None, None, None, 1280)  4049571
# _________________________________________________________________
# global_average_pooling2d_3 ( (None, 1280)              0
# _________________________________________________________________
# dense_5 (Dense)              (None, 64)                81984
# _________________________________________________________________
# dense_6 (Dense)              (None, 101)               6565
# _________________________________________________________________
# softmax_float32_layer (Activ (None, 101)               0
# =================================================================
# Total params: 4,138,120
# Trainable params: 88,549
# Non-trainable params: 4,049,571
# _________________________________________________________________

# %%
model_1.compile(
    loss = 'categorical_crossentropy',
    optimizer = Adam(),
    metrics = ['accuracy'],
)

history_1 = model_1.fit(
    train_data,
    epochs = 10,
    steps_per_epoch = len(train_data),
    validation_data = test_data,
    validation_steps = int(0.15 * len(test_data)),
    callbacks = [
        early_Stopping,
        checkpoint_callback,
    ]
)
# Out:
# Epoch 1/10
#    3/2368 [..............................] - ETA: 68:03:22 - loss: nan - accuracy: 0.0208
